# %% [raw]
# """
# @author: Hongjian Qi
# """

# %% [markdown]
# summary:
# 1. 10 original columns, all numeric
# 2. there is duplication in the client ids
# 3. test contain product not in train

# %%
# %matplotlib inline
from IPython.display import display
from itertools import chain
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import preprocessing
from sklearn.cross_validation import train_test_split
import pandas as pd
import numpy as np
import scipy as sc
from sklearn import preprocessing
from collections import Counter
from utils import *

import seaborn as sns
sns.set(style="white", color_codes=True)


#import random
# n =  6999251  #number of rows in the file 6999251 for test  74180464 for train
# s = 10000 #desired sample size
# file = "../data/test.csv"
# skip = sorted(random.sample(xrange(1,n),n-s))
# df = pd.read_csv(file, skiprows=skip)
# df.to_csv("../small_data/train.csv",index=False)

# %%
train_file = "../small_data/train.csv"
test_file = "../small_data/test.csv"
sample_submission = "../data/sample_submission.csv"
submission_filename = "test_submission.csv"

# translate spanish into english
train_head = ['Week', 'store_id', 'Channel_ID', 'Route_ID', 'Client_ID', 'Product_ID',
             'Sales_unit_this_week', 'Sales revenue this week',
             'Returns unit next week', 'Returns revenue next week', 
             'Adjusted Demand']

# %%
train = pd.read_csv(train_file, delimiter=',') #, nrows=10000)
test = pd.read_csv(test_file, delimiter=',')
print('Size of training set: ' + str(train.shape))
print('Size of testing set: ' + str(test.shape))
display(train.head())
display(test.head())
# Out:
# Size of training set: (10001, 11)
# Size of testing set: (10000, 7)
#    Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0       3        1111         1      1005       49364        32802
# 1       3        1111         1      1024       39105         1146
# 2       3        1111         1      1411     1606991         1309
# 3       3        1111         1      1629       65675        40217
# 4       3        1111         1      2104       49956        43058
#
#    Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  Demanda_uni_equil
# 0              2      23.82                0          0.0                2.1
# 1              3      64.17                0          0.0                3.0
# 2             11      74.36                0          0.0               11.0
# 3              4      35.92                0          0.0                4.0
# 4              6      56.10                0          0.0                6.0
#      id  Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID
# 0   108      11        1556         1      1005      894242        43188
# 1  3207      11        2018         1      1219      446663         1220
# 2  3797      10        1685        11      5701      279686         1220
# 3  6285      10        1656         1      1225     4129017         1238
# 4  6394      11        1122         1      1054      591593         1109

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 11 columns):
# Semana               10001 non-null int64
# Agencia_ID           10001 non-null int64
# Canal_ID             10001 non-null int64
# Ruta_SAK             10001 non-null int64
# Cliente_ID           10001 non-null int64
# Producto_ID          10001 non-null int64
# Venta_uni_hoy        10001 non-null int64
# Venta_hoy            10001 non-null float64
# Dev_uni_proxima      10001 non-null int64
# Dev_proxima          10001 non-null float64
# Demanda_uni_equil    10001 non-null float64
# dtypes: float64(3), int64(8)
# memory usage: 859.5 KB

# %%
for col in train.columns:
    print ('column name: %s, %d unique value')% (col, len(train[col].unique()))
train.describe()
# Out:
# column name: Semana, 7 unique value
# column name: Agencia_ID, 440 unique value
# column name: Canal_ID, 8 unique value
# column name: Ruta_SAK, 1246 unique value
# column name: Cliente_ID, 9874 unique value
# column name: Producto_ID, 544 unique value
# column name: Venta_uni_hoy, 113 unique value
# column name: Venta_hoy, 1582 unique value
# column name: Dev_uni_proxima, 23 unique value
# column name: Dev_proxima, 178 unique value
# column name: Demanda_uni_equil, 115 unique value
#              Semana    Agencia_ID      Canal_ID      Ruta_SAK    Cliente_ID  \
# count  10001.000000  10001.000000  10001.000000  10001.000000  1.000100e+04
# mean       5.981302   2521.671233      1.399660   2145.660234  1.804082e+06
# std        2.014684   4055.055780      1.513921   1508.163610  1.850360e+06
# min        3.000000   1110.000000      1.000000      2.000000  6.500000e+01
# 25%        4.000000   1312.000000      1.000000   1164.000000  3.541720e+05
# 50%        6.000000   1613.000000      1.000000   1294.000000  1.190325e+06
# 75%        8.000000   2034.000000      1.000000   2804.000000  2.367041e+06
# max        9.000000  25759.000000     11.000000   9054.000000  1.035181e+07
#
#         Producto_ID  Venta_uni_hoy     Venta_hoy  Dev_uni_proxima  \
# count  10001.000000   10001.000000  10001.000000     10001.000000
# mean   20902.736526       6.985101     62.259936         0.123188
# std    18670.478317      15.487126    198.883462         1.472896
# min       72.000000       0.000000      0.000000         0.000000
# 25%     1242.000000       2.000000     16.760000         0.000000
# 50%    30549.000000       3.000000     30.020000         0.000000
# 75%    37361.000000       7.000000     56.940000         0.000000
# max    49994.000000     451.000000  10354.960000        54.000000
#
#         Dev_proxima  Demanda_uni_equil
# count  10001.000000        10001.00000
# mean       1.066439            6.90112
# std       11.331303           15.33455
# min        0.000000            0.00000
# 25%        0.000000            2.00000
# 50%        0.000000            3.00000
# 75%        0.000000            7.00000
# max      480.000000          449.00000

# %%
display(train.Demanda_uni_equil.hist())

# %%
print sum(train.Demanda_uni_equil < 50)
print sum(train.Demanda_uni_equil >= 50)
train[train.Demanda_uni_equil < 50].Demanda_uni_equil.hist(bins = 100)
# Out:
# 9882
# 119

# %%
hist = train.hist()

# %%
fig, axes = plt.subplots(nrows=11)
for i, yvar in enumerate(train.columns):
    axes[i].scatter(train[yvar], train['Demanda_uni_equil'])

# %%
sns.jointplot(x="Ruta_SAK", y="Demanda_uni_equil", data=train, size=5)
