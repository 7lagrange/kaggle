# %% [raw]
# """
# @author: Hongjian Qi
# """

# %% [markdown]
# summary:
# 1. 10 original columns, all numeric

# %%
# %matplotlib inline
from IPython.display import display
from itertools import chain
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import preprocessing
from sklearn.cross_validation import train_test_split
import pandas as pd
import numpy as np
import scipy as sc
from sklearn import preprocessing
from collections import Counter
from utils import *

import seaborn as sns
sns.set(style="white", color_codes=True)

# %%
train_file = "../data/train.csv"
test_file = "../data/test.csv"
sample_submission = "../data/sample_submission.csv"
submission_filename = "test_submission.csv"

# %%
train = pd.read_csv('../data/train.csv',delimiter=',') #, nrows=10000)
test = pd.read_csv('../data/test.csv',delimiter=',', nrows=10000)
print('Size of training set: ' + str(train.shape))
print('Size of testing set: ' + str(test.shape))
display(train.head())
display(test.head())
# Out:
# Size of training set: (74180464, 11)
# Size of testing set: (10000, 7)
#    Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0       3        1110         7      3301       15766         1212
# 1       3        1110         7      3301       15766         1216
# 2       3        1110         7      3301       15766         1238
# 3       3        1110         7      3301       15766         1240
# 4       3        1110         7      3301       15766         1242
#
#    Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  Demanda_uni_equil
# 0              3      25.14                0          0.0                  3
# 1              4      33.52                0          0.0                  4
# 2              4      39.32                0          0.0                  4
# 3              4      33.52                0          0.0                  4
# 4              3      22.92                0          0.0                  3
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74180464 entries, 0 to 74180463
# Data columns (total 11 columns):
# Semana               int64
# Agencia_ID           int64
# Canal_ID             int64
# Ruta_SAK             int64
# Cliente_ID           int64
# Producto_ID          int64
# Venta_uni_hoy        int64
# Venta_hoy            float64
# Dev_uni_proxima      int64
# Dev_proxima          float64
# Demanda_uni_equil    int64
# dtypes: float64(2), int64(9)
# memory usage: 6.1 GB

# %%
for col in train.columns:
    print ('column name: %s, %d unique value')% (col, len(train[col].unique()))
train.describe()
# Out:
# column name: Semana, 7 unique value
# column name: Agencia_ID, 552 unique value
# column name: Canal_ID, 9 unique value
# column name: Ruta_SAK, 3603 unique value
# column name: Cliente_ID, 880604 unique value
# column name: Producto_ID, 1799 unique value
# column name: Venta_uni_hoy, 2116 unique value
# column name: Venta_hoy, 78140 unique value
# column name: Dev_uni_proxima, 558 unique value
# column name: Dev_proxima, 14707 unique value
# column name: Demanda_uni_equil, 2091 unique value
#              Semana    Agencia_ID      Canal_ID      Ruta_SAK    Cliente_ID  \
# count  7.418046e+07  7.418046e+07  7.418046e+07  7.418046e+07  7.418046e+07
# mean   5.950021e+00  2.536509e+03  1.383181e+00  2.114855e+03  1.802119e+06
# std    2.013175e+00  4.075124e+03  1.463266e+00  1.487744e+03  2.349577e+06
# min    3.000000e+00  1.110000e+03  1.000000e+00  1.000000e+00  2.600000e+01
# 25%    4.000000e+00  1.312000e+03  1.000000e+00  1.161000e+03  3.567670e+05
# ...

# %%
display(train.Demanda_uni_equil.hist())

# %%
print sum(train.Demanda_uni_equil < 50)
train[train.Demanda_uni_equil < 50].Demanda_uni_equil.hist(bins = 100)
# Out:
# 73112025

# %%
hist = train.hist()

# %%
fig, axes = plt.subplots(nrows=11)
for i, yvar in enumerate(train.columns):
    axes[i].scatter(train[yvar], train['Demanda_uni_equil'])
